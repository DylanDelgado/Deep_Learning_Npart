# %%
import torch
import h5py
import uproot
from matplotlib import pyplot as plt
print("torch", torch.__version__)
print("python device available:", "mps" if torch.backends.mps.is_available() else ("cuda" if torch.cuda.is_available() else "cpu"))
# Out:
# torch 2.12.1
# python device available: cuda

# %%
file = uproot.open("~/research/Data/combined_100k.root")
file.keys()
# Out:
# ['urqmd;1']

# %%
tree = file["urqmd"]

# %%
print(tree)
# Out:
# <TTree 'urqmd1' (7 branches) at 0x728fe096fa10>

# %%
tree.num_entries
# Out:
# 100000

# %%
tree.keys()
# Out:
# ['mul', 'b', 'Npart', 'pid', 'px', 'py', 'pz']

# %%
tree.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# mul                  | int32_t                  | AsDtype('>i4')
# b                    | float                    | AsDtype('>f4')
# Npart                | int32_t                  | AsDtype('>i4')
# pid                  | int32_t[]                | AsJagged(AsDtype('>i4'))
# px                   | float[]                  | AsJagged(AsDtype('>f4'))
# py                   | float[]                  | AsJagged(AsDtype('>f4'))
# pz                   | float[]                  | AsJagged(AsDtype('>f4'))

# %%
b = tree["b"].array()

# %%
print(b)
# Out:
# [13.8, 8.05, 11.6, 10.5, 4.54, 12.1, ..., 12.9, 15.8, 4.09, 8.41, 13.7, 9.66]

# %%
plt.sho
